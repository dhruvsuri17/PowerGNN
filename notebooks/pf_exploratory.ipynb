# %%
import pickle
import os
import sys

# Get the absolute path of the project root directory
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

if project_root not in sys.path:
    sys.path.append(project_root)

# Define the directory and file path
save_dir = "../data/parsed/"
load_path = os.path.join(save_dir, "builder.pkl")

# Load the builder object
with open(load_path, "rb") as f:
    builder = pickle.load(f)

# %%
sample = builder.run(builder.timestamps[0])
sample
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (118 elements)
#    - load (91 elements)
#    - gen (321 elements)
#    - ext_grid (1 element)
#    - line (177 elements)
#    - trafo (9 elements)
#    - bus_geodata (118 elements)
#  and the following results tables:
#    - res_bus (118 elements)
#    - res_line (177 elements)
#    - res_trafo (9 elements)
#    - res_ext_grid (1 element)
#    - res_load (91 elements)
#    - res_gen (321 elements)

# %%
import pandas as pd

for attr in dir(sample):
    if isinstance(getattr(sample, attr), pd.DataFrame):  # Check if it's a DataFrame
        print(f"🔹 {attr}.head():")
        print(getattr(sample, attr).head())  # Show first few rows
        print("\n" + "-"*80 + "\n")  # Separator
# Out:
# 🔹 _empty_res_asymmetric_load.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_asymmetric_load_3ph.head():
# Empty DataFrame
# Columns: [p_a_mw, q_a_mvar, p_b_mw, q_b_mvar, p_c_mw, q_c_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_asymmetric_sgen.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_asymmetric_sgen_3ph.head():
# Empty DataFrame
# Columns: [p_a_mw, q_a_mvar, p_b_mw, q_b_mvar, p_c_mw, q_c_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_bus.head():
# Empty DataFrame
# Columns: [vm_pu, va_degree, p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_bus_3ph.head():
# Empty DataFrame
# Columns: [vm_a_pu, va_a_degree, vm_b_pu, va_b_degree, vm_c_pu, va_c_degree, p_a_mw, q_a_mvar, p_b_mw, q_b_mvar, p_c_mw, q_c_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_dcline.head():
# Empty DataFrame
# Columns: [p_from_mw, q_from_mvar, p_to_mw, q_to_mvar, pl_mw, vm_from_pu, va_from_degree, vm_to_pu, va_to_degree]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_ext_grid.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_ext_grid_3ph.head():
# Empty DataFrame
# Columns: [p_a_mw, q_a_mvar, p_b_mw, q_b_mvar, p_c_mw, q_c_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_gen.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar, va_degree, vm_pu]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_impedance.head():
# Empty DataFrame
# Columns: [p_from_mw, q_from_mvar, p_to_mw, q_to_mvar, pl_mw, ql_mvar, i_from_ka, i_to_ka]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_line.head():
# Empty DataFrame
# Columns: [p_from_mw, q_from_mvar, p_to_mw, q_to_mvar, pl_mw, ql_mvar, i_from_ka, i_to_ka, i_ka, vm_from_pu, va_from_degree, vm_to_pu, va_to_degree, loading_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_line_3ph.head():
# Empty DataFrame
# Columns: [p_a_from_mw, q_a_from_mvar, p_b_from_mw, q_b_from_mvar, q_c_from_mvar, p_a_to_mw, q_a_to_mvar, p_b_to_mw, q_b_to_mvar, p_c_to_mw, q_c_to_mvar, p_a_l_mw, q_a_l_mvar, p_b_l_mw, q_b_l_mvar, p_c_l_mw, q_c_l_mvar, i_a_from_ka, i_a_to_ka, i_b_from_ka, i_b_to_ka, i_c_from_ka, i_c_to_ka, i_a_ka, i_b_ka, i_c_ka, i_n_from_ka, i_n_to_ka, i_n_ka, loading_a_percent, loading_b_percent, loading_c_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_load.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_load_3ph.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_motor.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_protection.head():
# Empty DataFrame
# Columns: [switch_id, prot_type, trip_melt, act_param, act_param_val, trip_melt_time_s]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_sgen.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_sgen_3ph.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_shunt.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar, vm_pu]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_ssc.head():
# Empty DataFrame
# Columns: [q_mvar, vm_internal_pu, va_internal_degree, vm_pu, va_degree]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_storage.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_storage_3ph.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_svc.head():
# Empty DataFrame
# Columns: [thyristor_firing_angle_degree, x_ohm, q_mvar, vm_pu, va_degree]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_switch.head():
# Empty DataFrame
# Columns: [i_ka, loading_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_tcsc.head():
# Empty DataFrame
# Columns: [thyristor_firing_angle_degree, x_ohm, p_from_mw, q_from_mvar, p_to_mw, q_to_mvar, pl_mw, ql_mvar, i_ka, vm_from_pu, va_from_degree, vm_to_pu, va_to_degree]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_trafo.head():
# Empty DataFrame
# Columns: [p_hv_mw, q_hv_mvar, p_lv_mw, q_lv_mvar, pl_mw, ql_mvar, i_hv_ka, i_lv_ka, vm_hv_pu, va_hv_degree, vm_lv_pu, va_lv_degree, loading_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_trafo3w.head():
# Empty DataFrame
# Columns: [p_hv_mw, q_hv_mvar, p_mv_mw, q_mv_mvar, p_lv_mw, q_lv_mvar, pl_mw, ql_mvar, i_hv_ka, i_mv_ka, i_lv_ka, vm_hv_pu, va_hv_degree, vm_mv_pu, va_mv_degree, vm_lv_pu, va_lv_degree, va_internal_degree, vm_internal_pu, loading_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_trafo_3ph.head():
# Empty DataFrame
# Columns: [p_a_hv_mw, q_a_hv_mvar, p_b_hv_mw, q_b_hv_mvar, p_c_hv_mw, q_c_hv_mvar, p_a_lv_mw, q_a_lv_mvar, p_b_lv_mw, q_b_lv_mvar, p_c_lv_mw, q_c_lv_mvar, p_a_l_mw, q_a_l_mvar, p_b_l_mw, q_b_l_mvar, p_c_l_mw, q_c_l_mvar, i_a_hv_ka, i_a_lv_ka, i_b_hv_ka, i_b_lv_ka, i_c_hv_ka, i_c_lv_ka, loading_a_percent, loading_b_percent, loading_c_percent, loading_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_ward.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar, vm_pu]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 _empty_res_xward.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar, vm_pu, va_internal_degree, vm_internal_pu]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 asymmetric_load.head():
# Empty DataFrame
# Columns: [name, bus, p_a_mw, q_a_mvar, p_b_mw, q_b_mvar, p_c_mw, q_c_mvar, sn_mva, scaling, in_service, type]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 asymmetric_sgen.head():
# Empty DataFrame
# Columns: [name, bus, p_a_mw, q_a_mvar, p_b_mw, q_b_mvar, p_c_mw, q_c_mvar, sn_mva, scaling, in_service, type, current_source]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 bus.head():
#       name  vn_kv type zone  in_service  min_vm_pu  max_vm_pu
# 0  bus_001  138.0    b   r1        True        0.8        1.2
# 1  bus_002  138.0    b   r1        True        0.8        1.2
# 2  bus_003  138.0    b   r1        True        0.8        1.2
# 3  bus_004  138.0    b   r1        True        0.8        1.2
# 4  bus_005  138.0    b   r1        True        0.8        1.2
#
# --------------------------------------------------------------------------------
#
# 🔹 bus_geodata.head():
#        x      y coords
# 0  626.0 -324.0    NaN
# 1  678.0 -324.0    NaN
# 2  574.0 -308.0    NaN
# 3  522.0 -212.0    NaN
# 4  418.0 -244.0    NaN
#
# --------------------------------------------------------------------------------
#
# 🔹 characteristic.head():
# Empty DataFrame
# Columns: [object]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 controller.head():
# Empty DataFrame
# Columns: [object, in_service, order, level, initial_run, recycle]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 dcline.head():
# Empty DataFrame
# Columns: [name, from_bus, to_bus, p_mw, loss_percent, loss_mw, vm_from_pu, vm_to_pu, max_p_mw, min_q_from_mvar, min_q_to_mvar, max_q_from_mvar, max_q_to_mvar, in_service]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 ext_grid.head():
#       name  bus     vm_pu  va_degree  slack_weight  in_service  controllable
# 0  bus_069   68  1.199998        0.0           1.0        True          True
#
# --------------------------------------------------------------------------------
#
# 🔹 gen.head():
#           name  bus      p_mw     vm_pu  sn_mva  min_q_mvar  max_q_mvar  \
# 0  biomass_001   11  0.520871  1.200000     NaN   -0.315000    0.735000
# 1  biomass_002   11  0.520871  1.200000     NaN   -0.315000    0.735000
# 2  biomass_003  102  0.248849  1.192039     NaN   -0.074988    0.174972
# 3  biomass_004  102  0.248849  1.192039     NaN   -0.074988    0.174972
# 4  biomass_005   11  0.224156  1.200000     NaN   -0.135018    0.315042
#
#    scaling  slack  in_service  slack_weight type  controllable  min_p_mw  \
# 0      1.0  False         1.0           0.0  NaN          True       0.0
# 1      1.0  False         1.0           0.0  NaN          True       0.0
# 2      1.0  False         1.0           0.0  NaN          True       0.0
# 3      1.0  False         1.0           0.0  NaN          True       0.0
# 4      1.0  False         1.0           0.0  NaN          True       0.0
#
#    max_p_mw
# 0   1.05000
# 1   1.05000
# 2   0.24996
# 3   0.24996
# 4   0.45006
#
# --------------------------------------------------------------------------------
#
# 🔹 group.head():
# Empty DataFrame
# Columns: [name, element_type, element, reference_column]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 impedance.head():
# Empty DataFrame
# Columns: [name, from_bus, to_bus, rft_pu, xft_pu, rtf_pu, xtf_pu, sn_mva, in_service]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 line.head():
#                name std_type  from_bus  to_bus  length_km  r_ohm_per_km  \
# 0  branch_001_002_1      NaN         0       1        1.0      5.770332
# 1  branch_001_003_1      NaN         0       2        1.0      2.456676
# 2  branch_002_012_1      NaN         1      11        1.0      3.561228
# 3  branch_003_005_1      NaN         2       4        1.0      4.589604
# 4  branch_003_012_1      NaN         2      11        1.0      9.217296
#
#    x_ohm_per_km  c_nf_per_km  g_us_per_km  max_i_ka   df  parallel type  \
# 0     19.024956   353.789080          0.0  2.510219  1.0         1   ol
# 1      8.074656   150.708577          0.0  2.510219  1.0         1   ol
# 2     11.731104   218.959227          0.0  2.510219  1.0         1   ol
# 3     20.567520   395.575192          0.0  2.510219  1.0         1   ol
# 4     30.470400   565.505381          0.0  2.510219  1.0         1   ol
#
#    in_service  max_loading_percent
# 0        True                100.0
# 1        True                100.0
# 2        True                100.0
# 3        True                100.0
# 4        True                100.0
#
# --------------------------------------------------------------------------------
#
# 🔹 line_geodata.head():
# Empty DataFrame
# Columns: [coords]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 load.head():
#        name  bus        p_mw     q_mvar  const_z_percent  const_i_percent  \
# 0  load_001    0  174.701149  27.944439              0.0              0.0
# 1  load_002    1   68.505820  30.816325              0.0              0.0
# 2  load_003    2  133.591197  34.269047              0.0              0.0
# 3  load_004    3  102.774871  41.109949              0.0              0.0
# 4  load_006    5  178.121592  75.346724              0.0              0.0
#
#    sn_mva  scaling  in_service type  controllable
# 0     NaN      1.0         1.0  wye         False
# 1     NaN      1.0         1.0  wye         False
# 2     NaN      1.0         1.0  wye         False
# 3     NaN      1.0         1.0  wye         False
# 4     NaN      1.0         1.0  wye         False
#
# --------------------------------------------------------------------------------
#
# 🔹 measurement.head():
# Empty DataFrame
# Columns: [name, measurement_type, element_type, element, value, std_dev, side]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 motor.head():
# Empty DataFrame
# Columns: [name, bus, pn_mech_mw, loading_percent, cos_phi, cos_phi_n, efficiency_percent, efficiency_n_percent, lrc_pu, vn_kv, scaling, in_service, rx]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 poly_cost.head():
# Empty DataFrame
# Columns: [element, et, cp0_eur, cp1_eur_per_mw, cp2_eur_per_mw2, cq0_eur, cq1_eur_per_mvar, cq2_eur_per_mvar2]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 pwl_cost.head():
# Empty DataFrame
# Columns: [power_type, element, et, points]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_asymmetric_load.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_asymmetric_load_3ph.head():
# Empty DataFrame
# Columns: [p_a_mw, q_a_mvar, p_b_mw, q_b_mvar, p_c_mw, q_c_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_asymmetric_sgen.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_asymmetric_sgen_3ph.head():
# Empty DataFrame
# Columns: [p_a_mw, q_a_mvar, p_b_mw, q_b_mvar, p_c_mw, q_c_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_bus.head():
#       vm_pu  va_degree        p_mw     q_mvar
# 0  1.114680  -9.605718  174.701149  27.944439
# 1  1.148707  -5.777126   68.505820  30.816325
# 2  1.131708  -8.039705  133.591197  34.269047
# 3  1.197012  -2.646202  -23.409049 -35.890231
# 4  1.196556  -2.539347    0.000000   0.000000
#
# --------------------------------------------------------------------------------
#
# 🔹 res_bus_3ph.head():
# Empty DataFrame
# Columns: [vm_a_pu, va_a_degree, vm_b_pu, va_b_degree, vm_c_pu, va_c_degree, p_a_mw, q_a_mvar, p_b_mw, q_b_mvar, p_c_mw, q_c_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_bus_est.head():
# Empty DataFrame
# Columns: [vm_pu, va_degree, p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_bus_sc.head():
# Empty DataFrame
# Columns: []
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_dcline.head():
# Empty DataFrame
# Columns: [p_from_mw, q_from_mvar, p_to_mw, q_to_mvar, pl_mw, vm_from_pu, va_from_degree, vm_to_pu, va_to_degree]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_ext_grid.head():
#         p_mw      q_mvar
# 0  45.905686 -148.869651
#
# --------------------------------------------------------------------------------
#
# 🔹 res_ext_grid_3ph.head():
# Empty DataFrame
# Columns: [p_a_mw, q_a_mvar, p_b_mw, q_b_mvar, p_c_mw, q_c_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_ext_grid_sc.head():
# Empty DataFrame
# Columns: []
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_gen.head():
#        p_mw    q_mvar  va_degree     vm_pu
# 0  0.520871  0.157476  -2.047699  1.200000
# 1  0.520871  0.157476  -2.047699  1.200000
# 2  0.248849  0.136986  -2.249286  1.192039
# 3  0.248849  0.136986  -2.249286  1.192039
# 4  0.224156  0.067499  -2.047699  1.200000
#
# --------------------------------------------------------------------------------
#
# 🔹 res_gen_sc.head():
# Empty DataFrame
# Columns: []
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_impedance.head():
# Empty DataFrame
# Columns: [p_from_mw, q_from_mvar, p_to_mw, q_to_mvar, pl_mw, ql_mvar, i_from_ka, i_to_ka]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_impedance_est.head():
# Empty DataFrame
# Columns: [p_from_mw, q_from_mvar, p_to_mw, q_to_mvar, pl_mw, ql_mvar, i_from_ka, i_to_ka]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_line.head():
#     p_from_mw  q_from_mvar     p_to_mw  q_to_mvar     pl_mw    ql_mvar  \
# 0  -88.124190    -9.956633   90.035103  13.003181  1.910913   3.046548
# 1  -86.576959   -17.987807   87.386293  19.282852  0.809334   1.295046
# 2 -158.540923   -43.819506  162.362410  54.238947  3.821487  10.419441
# 3 -127.699924   -35.502127  130.981938  46.358143  3.282014  10.856016
# 4  -93.277566   -18.049771   96.655762  23.694211  3.378195   5.644440
#
#    i_from_ka   i_to_ka      i_ka  vm_from_pu  va_from_degree  vm_to_pu  \
# 0   0.332859  0.331318  0.332859    1.114680       -9.605718  1.148707
# 1   0.331886  0.330821  0.331886    1.114680       -9.605718  1.131708
# 2   0.599070  0.596813  0.599070    1.148707       -5.777126  1.200000
# 3   0.489985  0.485809  0.489985    1.131708       -8.039705  1.196556
# 4   0.351225  0.346960  0.351225    1.131708       -8.039705  1.200000
#
#    va_to_degree  loading_percent
# 0     -5.777126        13.260141
# 1     -8.039705        13.221411
# 2     -2.047699        23.865260
# 3     -2.539347        19.519616
# 4     -2.047699        13.991807
#
# --------------------------------------------------------------------------------
#
# 🔹 res_line_3ph.head():
# Empty DataFrame
# Columns: [p_a_from_mw, q_a_from_mvar, p_b_from_mw, q_b_from_mvar, q_c_from_mvar, p_a_to_mw, q_a_to_mvar, p_b_to_mw, q_b_to_mvar, p_c_to_mw, q_c_to_mvar, p_a_l_mw, q_a_l_mvar, p_b_l_mw, q_b_l_mvar, p_c_l_mw, q_c_l_mvar, i_a_from_ka, i_a_to_ka, i_b_from_ka, i_b_to_ka, i_c_from_ka, i_c_to_ka, i_a_ka, i_b_ka, i_c_ka, i_n_from_ka, i_n_to_ka, i_n_ka, loading_a_percent, loading_b_percent, loading_c_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_line_est.head():
# Empty DataFrame
# Columns: [p_from_mw, q_from_mvar, p_to_mw, q_to_mvar, pl_mw, ql_mvar, i_from_ka, i_to_ka, i_ka, vm_from_pu, va_from_degree, vm_to_pu, va_to_degree, loading_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_line_sc.head():
# Empty DataFrame
# Columns: []
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_load.head():
#          p_mw     q_mvar
# 0  174.701149  27.944439
# 1   68.505820  30.816325
# 2  133.591197  34.269047
# 3  102.774871  41.109949
# 4  178.121592  75.346724
#
# --------------------------------------------------------------------------------
#
# 🔹 res_load_3ph.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_motor.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_sgen.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_sgen_3ph.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_sgen_sc.head():
# Empty DataFrame
# Columns: []
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_shunt.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar, vm_pu]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_shunt_3ph.head():
# Empty DataFrame
# Columns: []
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_ssc.head():
# Empty DataFrame
# Columns: [q_mvar, vm_internal_pu, va_internal_degree, vm_pu, va_degree]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_storage.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_storage_3ph.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_svc.head():
# Empty DataFrame
# Columns: [thyristor_firing_angle_degree, x_ohm, q_mvar, vm_pu, va_degree]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_switch.head():
# Empty DataFrame
# Columns: [i_ka, loading_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_switch_est.head():
# Empty DataFrame
# Columns: [i_ka, loading_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_switch_sc.head():
# Empty DataFrame
# Columns: []
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_tcsc.head():
# Empty DataFrame
# Columns: [thyristor_firing_angle_degree, x_ohm, p_from_mw, q_from_mvar, p_to_mw, q_to_mvar, pl_mw, ql_mvar, i_ka, vm_from_pu, va_from_degree, vm_to_pu, va_to_degree]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_trafo.head():
#       p_hv_mw   q_hv_mvar     p_lv_mw   q_lv_mvar         pl_mw    ql_mvar  \
# 0  242.792193   63.093762 -242.792193  -51.604196  0.000000e+00  11.489566
# 1  281.018389  166.967013 -281.018389 -140.761494  0.000000e+00  26.205519
# 2  276.593245  110.845827 -276.593245  -87.905995  0.000000e+00  22.939832
# 3  114.420818  128.124628 -114.420818 -120.908235 -9.947598e-14   7.216393
# 4   21.267467   47.045177  -21.267467  -46.344192 -1.065814e-14   0.700985
#
#     i_hv_ka   i_lv_ka  vm_hv_pu  va_hv_degree  vm_lv_pu  va_lv_degree  \
# 0  0.352436  0.867874  1.191146      0.028400  1.196556     -2.539347
# 1  0.456577  1.095784  1.198098      5.494066  1.200000      1.383600
# 2  0.423866  1.017278  1.176456     -1.818702  1.193596     -6.026207
# 3  0.248287  0.580370  1.157810     -2.276878  1.199999     -3.931552
# 4  0.074286  0.178288  1.163066      0.704646  1.196557      0.380186
#
#    loading_percent
# 0        12.388282
# 1        16.048875
# 2        14.899070
# 3         8.727382
# 4         2.611203
#
# --------------------------------------------------------------------------------
#
# 🔹 res_trafo3w.head():
# Empty DataFrame
# Columns: [p_hv_mw, q_hv_mvar, p_mv_mw, q_mv_mvar, p_lv_mw, q_lv_mvar, pl_mw, ql_mvar, i_hv_ka, i_mv_ka, i_lv_ka, vm_hv_pu, va_hv_degree, vm_mv_pu, va_mv_degree, vm_lv_pu, va_lv_degree, va_internal_degree, vm_internal_pu, loading_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_trafo3w_est.head():
# Empty DataFrame
# Columns: [p_hv_mw, q_hv_mvar, p_mv_mw, q_mv_mvar, p_lv_mw, q_lv_mvar, pl_mw, ql_mvar, i_hv_ka, i_mv_ka, i_lv_ka, vm_hv_pu, va_hv_degree, vm_mv_pu, va_mv_degree, vm_lv_pu, va_lv_degree, va_internal_degree, vm_internal_pu, loading_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_trafo3w_sc.head():
# Empty DataFrame
# Columns: []
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_trafo_3ph.head():
# Empty DataFrame
# Columns: [p_a_hv_mw, q_a_hv_mvar, p_b_hv_mw, q_b_hv_mvar, p_c_hv_mw, q_c_hv_mvar, p_a_lv_mw, q_a_lv_mvar, p_b_lv_mw, q_b_lv_mvar, p_c_lv_mw, q_c_lv_mvar, p_a_l_mw, q_a_l_mvar, p_b_l_mw, q_b_l_mvar, p_c_l_mw, q_c_l_mvar, i_a_hv_ka, i_a_lv_ka, i_b_hv_ka, i_b_lv_ka, i_c_hv_ka, i_c_lv_ka, loading_a_percent, loading_b_percent, loading_c_percent, loading_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_trafo_est.head():
# Empty DataFrame
# Columns: [p_hv_mw, q_hv_mvar, p_lv_mw, q_lv_mvar, pl_mw, ql_mvar, i_hv_ka, i_lv_ka, vm_hv_pu, va_hv_degree, vm_lv_pu, va_lv_degree, loading_percent]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_trafo_sc.head():
# Empty DataFrame
# Columns: []
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_ward.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar, vm_pu]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 res_xward.head():
# Empty DataFrame
# Columns: [p_mw, q_mvar, vm_pu, va_internal_degree, vm_internal_pu]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 sgen.head():
# Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, scaling, in_service, type, current_source]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 shunt.head():
# Empty DataFrame
# Columns: [bus, name, q_mvar, p_mw, vn_kv, step, max_step, in_service]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 ssc.head():
# Empty DataFrame
# Columns: [name, bus, r_ohm, x_ohm, vm_internal_pu, va_internal_degree, set_vm_pu, controllable, in_service]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 storage.head():
# Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 svc.head():
# Empty DataFrame
# Columns: [name, bus, x_l_ohm, x_cvar_ohm, set_vm_pu, thyristor_firing_angle_degree, controllable, in_service, min_angle_degree, max_angle_degree]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 switch.head():
# Empty DataFrame
# Columns: [bus, element, et, type, closed, name, z_ohm, in_ka]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 tcsc.head():
# Empty DataFrame
# Columns: [name, from_bus, to_bus, x_l_ohm, x_cvar_ohm, set_p_to_mw, thyristor_firing_angle_degree, controllable, in_service]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 trafo.head():
#                name std_type  hv_bus  lv_bus       sn_mva  vn_hv_kv  vn_lv_kv  \
# 0  branch_008_005_1      NaN       7       4  1699.999779     345.0     138.0
# 1  branch_026_025_1      NaN      25      24  1699.999779     345.0     138.0
# 2  branch_030_017_1      NaN      29      16  1699.999779     345.0     138.0
# 3  branch_038_037_1      NaN      37      36  1699.999779     345.0     138.0
# 4  branch_063_059_1      NaN      62      58  1699.999779     345.0     138.0
#
#    vk_percent  vkr_percent  pfe_kw  i0_percent  shift_degree tap_side  \
# 0   45.389994          0.0     0.0         0.0           0.0       hv
# 1   64.939992          0.0     0.0         0.0           0.0       hv
# 2   65.959991          0.0     0.0         0.0           0.0       hv
# 3   63.749992          0.0     0.0         0.0           0.0       hv
# 4   65.619991          0.0     0.0         0.0           0.0       hv
#
#    tap_neutral  tap_min  tap_max  tap_step_percent  tap_step_degree  tap_pos  \
# 0            0      NaN      NaN               1.5              NaN       -1
# 1            0      NaN      NaN               4.0              NaN       -1
# 2            0      NaN      NaN               4.0              NaN       -1
# 3            0      NaN      NaN               6.5              NaN       -1
# 4            0      NaN      NaN               4.0              NaN       -1
#
#    tap_phase_shifter  parallel   df  in_service  max_loading_percent
# 0              False         1  1.0        True                100.0
# 1              False         1  1.0        True                100.0
# 2              False         1  1.0        True                100.0
# 3              False         1  1.0        True                100.0
# 4              False         1  1.0        True                100.0
#
# --------------------------------------------------------------------------------
#
# 🔹 trafo3w.head():
# Empty DataFrame
# Columns: [name, std_type, hv_bus, mv_bus, lv_bus, sn_hv_mva, sn_mv_mva, sn_lv_mva, vn_hv_kv, vn_mv_kv, vn_lv_kv, vk_hv_percent, vk_mv_percent, vk_lv_percent, vkr_hv_percent, vkr_mv_percent, vkr_lv_percent, pfe_kw, i0_percent, shift_mv_degree, shift_lv_degree, tap_side, tap_neutral, tap_min, tap_max, tap_step_percent, tap_step_degree, tap_pos, tap_at_star_point, in_service]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 ward.head():
# Empty DataFrame
# Columns: [name, bus, ps_mw, qs_mvar, qz_mvar, pz_mw, in_service]
# Index: []
#
# --------------------------------------------------------------------------------
#
# 🔹 xward.head():
# Empty DataFrame
# Columns: [name, bus, ps_mw, qs_mvar, qz_mvar, pz_mw, r_ohm, x_ohm, vm_pu, slack_weight, in_service]
# Index: []
#
# --------------------------------------------------------------------------------

# %%
import networkx as nx
import torch
import torch.nn as nn
import torch_geometric.nn as pyg_nn
from torch_geometric.data import Data
from torch_geometric.utils import from_networkx

def construct_nrel118_graph_sequence(builder, num_timesteps=10):
    """
    Constructs a sequence of PyTorch Geometric Data objects for the NREL 118-bus network.
    
    Args:
        builder: PandaPowerFlowBuilder instance
        num_timesteps: Number of timesteps to process
    
    Returns:
        List of PyG Data objects representing the power network state at each timestep
    """
    graph_sequence = []
    
    for t in range(min(num_timesteps, len(builder.timestamps))):
        sample = builder.run(builder.timestamps[t])
        G = nx.Graph()
        
        # Add nodes (buses) with their features
        for idx, bus in sample.bus.iterrows():
            res_bus = sample.res_bus.loc[idx] if idx in sample.res_bus.index else None
            G.add_node(idx, 
                      vn_kv=float(bus['vn_kv']),
                      min_vm_pu=float(bus['min_vm_pu']),
                      max_vm_pu=float(bus['max_vm_pu']),
                      type=bus['type'],
                      zone=bus['zone'],
                      vm_pu=float(res_bus['vm_pu']) if res_bus is not None else 1.0,
                      va_degree=float(res_bus['va_degree']) if res_bus is not None else 0.0,
                      p_mw=float(res_bus['p_mw']) if res_bus is not None else 0.0,
                      q_mvar=float(res_bus['q_mvar']) if res_bus is not None else 0.0)
        
        # Add edges (transmission lines)
        for idx, line in sample.line.iterrows():
            res_line = sample.res_line.loc[idx] if idx in sample.res_line.index else None
            G.add_edge(line['from_bus'], line['to_bus'],
                      r_ohm_per_km=float(line['r_ohm_per_km']),
                      x_ohm_per_km=float(line['x_ohm_per_km']),
                      length_km=float(line['length_km']),
                      p_from=float(res_line['p_from_mw']) if res_line is not None else 0.0,
                      q_from=float(res_line['q_from_mvar']) if res_line is not None else 0.0,
                      p_to=float(res_line['p_to_mw']) if res_line is not None else 0.0,
                      q_to=float(res_line['q_to_mvar']) if res_line is not None else 0.0,
                      loading=float(res_line['loading_percent']) if res_line is not None else 0.0)

        # Add transformers as edges
        for idx, trafo in sample.trafo.iterrows():
            res_trafo = sample.res_trafo.loc[idx] if idx in sample.res_trafo.index else None
            G.add_edge(trafo['hv_bus'], trafo['lv_bus'],
                      p_from=float(res_trafo['p_hv_mw']) if res_trafo is not None else 0.0,
                      q_from=float(res_trafo['q_hv_mvar']) if res_trafo is not None else 0.0,
                      p_to=float(res_trafo['p_lv_mw']) if res_trafo is not None else 0.0,
                      q_to=float(res_trafo['q_lv_mvar']) if res_trafo is not None else 0.0,
                      loading=float(res_trafo['loading_percent']) if res_trafo is not None else 0.0)

        # Add generators as nodes
        for idx, gen in sample.gen.iterrows():
            res_gen = sample.res_gen.loc[idx] if idx in sample.res_gen.index else None
            bus_idx = gen['bus']
            if bus_idx in G.nodes:
                G.nodes[bus_idx]['gen_p_mw'] = float(res_gen['p_mw']) if res_gen is not None else 0.0
                G.nodes[bus_idx]['gen_q_mvar'] = float(res_gen['q_mvar']) if res_gen is not None else 0.0

        # Convert to PyG Data
        data = from_networkx(G)
        
        # Extract node features
        node_features = torch.tensor([[G.nodes[i]['vn_kv'], 
                                       G.nodes[i]['min_vm_pu'],
                                       G.nodes[i]['max_vm_pu'],
                                       G.nodes[i]['vm_pu'], 
                                       G.nodes[i]['va_degree'],
                                       G.nodes[i]['p_mw'], 
                                       G.nodes[i]['q_mvar']] 
                                      for i in G.nodes], 
                                     dtype=torch.float)
        
        # Ensure bidirectional edges match edge_index.shape[1]
        edge_features_list = []
        for u, v, d in G.edges(data=True):
            edge_features_list.append([d['r_ohm_per_km'], d['x_ohm_per_km'], d['p_from'], d['q_from'], d['p_to'], d['q_to'], d['loading']])
            edge_features_list.append([d['r_ohm_per_km'], d['x_ohm_per_km'], d['p_to'], d['q_to'], d['p_from'], d['q_from'], d['loading']])  # Duplicate

        edge_features = torch.tensor(edge_features_list, dtype=torch.float)
        
        data.x = node_features
        data.edge_attr = edge_features
        
        graph_sequence.append(data)
    
    return graph_sequence

# %%
graph_sequences = construct_nrel118_graph_sequence(builder,10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 graph_sequences = construct_nrel118_graph_sequence(builder,10)
#
# Cell In[17], line 71, in construct_nrel118_graph_sequence(builder, num_timesteps)
#      68         G.nodes[bus_idx]['gen_q_mvar'] = float(res_gen['q_mvar']) if res_gen is not None else 0.0
#      70 # Convert to PyG Data
# ---> 71 data = from_networkx(G)
#      73 # Extract node features
#      74 node_features = torch.tensor([[G.nodes[i]['vn_kv'],
#      75                                G.nodes[i]['min_vm_pu'],
#      76                                G.nodes[i]['max_vm_pu'],
#    (...)
#      81                               for i in G.nodes],
#      82                              dtype=torch.float)
#
# File ~/Code/PowerGNN/venv/lib/python3.12/site-packages/torch_geometric/utils/convert.py:256, in from_networkx(G, group_node_attrs, group_edge_attrs)
#     254 for i, (_, feat_dict) in enumerate(G.nodes(data=True)):
#     255     if set(feat_dict.keys()) != set(node_attrs):
# --> 256         raise ValueError('Not all nodes contain the same attributes')
#     257     for key, value in feat_dict.items():
#     258         data_dict[str(key)].append(value)
#
# ValueError: Not all nodes contain the same attributes
